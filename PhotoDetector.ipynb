# %%
# Import dependencies
from imageai.Detection import ObjectDetection
import warnings
warnings.filterwarnings('ignore')

# %%
# Variable to hold the path to the folder where our python file, RetinaNet model file and images are
import os
execution_path = os.getcwd()

# %%
detector = ObjectDetection()
detector.setModelTypeAsRetinaNet()
detector.setModelPath( os.path.join(execution_path , 'resnet50_coco_best_v2.1.0.h5'))
detector.loadModel()
custom_objects = detector.CustomObjects(person=True,car=False)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
detections = detector.detectCustomObjectsFromImage(input_image=os.path.join(execution_path ,"SampleImage1.jpg"), output_image_path=os.path.join(execution_path ,"SampleImage_Output1.jpg"), custom_objects=custom_objects, minimum_percentage_probability=60)
for eachObject in detections:print(eachObject["name"], eachObject["percentage_probability"] )
print()
# Out:
# person 92.89526343345642
# person 89.27202224731445
# person 89.23221826553345
# person 88.32718133926392
# person 87.51226663589478
# person 84.15852785110474
# person 84.1308057308197
# person 82.78510570526123
# person 82.0755124092102
# person 81.72297477722168
# person 79.44321632385254
# person 75.25129318237305
# person 73.84914755821228
# person 64.40125107765198
# person 62.4687135219574
# person 62.11315393447876

# %%
#To print the resulting image
from IPython.display import Image
Image("SampleImage_Output1.jpg")
